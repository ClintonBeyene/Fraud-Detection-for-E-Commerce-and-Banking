# %% [markdown]
# # Data Analysis and Preprocessing of IpAddress to Country

# %%
# Importing necessary lebraries
import numpy as np
import pandas as pd
import os
import sys

# %%
sys.path.append(os.path.join(os.path.abspath('../..')))

# %%
# Import modules
from src import data_loading as dl
from src import data_summarry as ds
from src import formatting as fm
from src import univariate_analysis as uv

# %%
ip_address_df = dl.load_data("IpAddress_to_Country.csv") # Maps IP addresses to countries

# %%
# Data overview 
ip_address_df.head()
# Out:
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %%
# Country ip address overview 
ds.data_summary(ip_address_df)
# Out:
# Snapshot:
#
# Rows                138846
# Columns                  3
# Missing cells   0 (0.00 %)
# Zeros           0 (0.00 %)
# Duplicate rows  0 (0.00 %)

# %%
# Country ip adress data types 
ds.data_types(ip_address_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_acf70">
#   <thead>
#     <tr>
#       <th id="T_acf70_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_acf70_level0_col1" class="col_heading level0 col1" >Inferred Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_acf70_row0_col0" class="data row0 col0" >lower_bound_ip_address</td>
#       <td id="T_acf70_row0_col1" class="data row0 col1" >numeric</td>
#     </tr>
#     <tr>
#       <td id="T_acf70_row1_col0" class="data row1 col0" >upper_bound_ip_address</td>
#       <td id="T_acf70_row1_col1" class="data row1 col1" >numeric</td>
#     </tr>
#     <tr>
#       <td id="T_acf70_row2_col0" class="data row2 col0" >country</td>
#       <td id="T_acf70_row2_col1" class="data row2 col1" >categorical</td>
#     </tr>
#   </tbody>
# </table>

# %%
ds.missing_values(ip_address_df)
# Out:
# There are no missing values

# %%
ds.constant_occurrence(ip_address_df)
# Out:
# <style type="text/css">
# #T_a0e04_row0_col2, #T_a0e04_row1_col2, #T_a0e04_row2_col2 {
#   width: 10em;
# }
# </style>
# <table id="T_a0e04">
#   <thead>
#     <tr>
#       <th id="T_a0e04_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_a0e04_level0_col1" class="col_heading level0 col1" ><i>0</i> Count</th>
#       <th id="T_a0e04_level0_col2" class="col_heading level0 col2" ><i>0</i> %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0e04_row0_col0" class="data row0 col0" >lower_bound_ip_address</td>
#       <td id="T_a0e04_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a0e04_row0_col2" class="data row0 col2" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_a0e04_row1_col0" class="data row1 col0" >upper_bound_ip_address</td>
#       <td id="T_a0e04_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_a0e04_row1_col2" class="data row1 col2" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_a0e04_row2_col0" class="data row2 col0" >country</td>
#       <td id="T_a0e04_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_a0e04_row2_col2" class="data row2 col2" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
ds.duplicate_row_count(ip_address_df)
# Out:
# There are no duplicated rows

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# * Univariate analysis
# * Bivariate analysis

# %%
# Distribution of categorical column
categorical_columns = ['country']  # Change to a categorical column to check on others 
uv.ip_categorical_distribution(ip_address_df, categorical_columns)
